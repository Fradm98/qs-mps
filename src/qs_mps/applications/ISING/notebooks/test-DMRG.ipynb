# %%
import numpy as np
from qs_mps.mps_class import MPS
from qs_mps.utils import tensor_shapes, truncation, create_sequential_colors, mps_to_vector
from qs_mps.sparse_hamiltonians_and_operators import *
from matplotlib import pyplot as plt

# %%
grid = np.linspace(0,2,32)
L = 12
chis = [2,4,8,16,32,64]
trunc_chi = True
trunc_tol = False
type_shape = "rectangular" # "trapezoidal"
long = "X"
trans = "Z"
eps = 0

mag = []
ene = []
entr = []
sv = []
overlap = []
for chi in chis:
    mag_chi = []
    ene_chi = []
    entr_chi = []
    sv_chi = []
    overlap_chi = []

    mag_exact = []
    ene_exact = []
    v0 = np.full(2**L, (1/np.sqrt(2))**L)
    sparse = True

    for h in grid:
        print(f"ground state search for h: {h}")
        chain = MPS(L=L,d=2,model="Ising",chi=chi, eps=eps, J=1, h=h)
        chain._random_state(seed=3, type_shape=type_shape)
        chain.canonical_form(trunc_chi=trunc_chi, trunc_tol=trunc_tol)
        energy, entropy, schmidt_vals = chain.DMRG(trunc_chi=trunc_chi, trunc_tol=trunc_tol, n_sweeps=8, conv_tol=1e-12, long=long, trans=trans, where=L//2)
        chain.order_param(op=long)
        mag_chi.append(chain.mpo_first_moment().real/L)
        ene_chi.append(energy[-1])
        entr_chi.append(entropy)
        sv_chi.append(schmidt_vals)

        H = Ising(L=L, h=h, eps=eps)
        e, v = diagonalization(H, sparse=sparse, v0=v0)
        gs = v[:,0]
        ene_exact.append(e[0])
        mag_exact.append((gs.conjugate().T @ magnetization(L=L) @ gs).real)
        v0 = gs

        psi_mps = mps_to_vector(chain.sites)
        overlap_chi.append((gs.T @ psi_mps).real)
    mag.append(mag_chi)
    ene.append(ene_chi)
    entr.append(entr_chi)
    sv.append(sv_chi)
    overlap.append(overlap_chi)
# Out:
# ground state search for h: 0.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.08069199998863041
# ##############################
# ground state search for h: 0.06451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 3 sweeps at site 2
# total iterations 45
# total time: 0.10874709999188781
# ##############################
# ground state search for h: 0.12903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 3 sweeps at site 2
# total iterations 45
# total time: 0.10851970000658184
# ##############################
# ground state search for h: 0.1935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 3 sweeps at site 2
# total iterations 45
# total time: 0.1429282000171952
# ##############################
# ground state search for h: 0.25806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 3 sweeps at site 2
# total iterations 45
# total time: 0.13067650003358722
# ##############################
# ground state search for h: 0.3225806451612903
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.18841040000552312
# ##############################
# ground state search for h: 0.3870967741935484
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.18449760001385584
# ##############################
# ground state search for h: 0.45161290322580644
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12795630004256964
# ##############################
# ground state search for h: 0.5161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.133474699978251
# ##############################
# ground state search for h: 0.5806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 7 sweeps at site 2
# total iterations 89
# total time: 0.17543289996683598
# ##############################
# ground state search for h: 0.6451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 7 sweeps at site 2
# total iterations 89
# total time: 0.2540840000147
# ##############################
# ground state search for h: 0.7096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1.822542117224657e-12
# instead of the convergence tolerance 1e-12
# total time: 0.2657711000065319
# ##############################
# ground state search for h: 0.7741935483870968
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1.1723599868673773e-10
# instead of the convergence tolerance 1e-12
# total time: 0.30805019999388605
# ##############################
# ground state search for h: 0.8387096774193548
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 7.228621594634888e-07
# instead of the convergence tolerance 1e-12
# total time: 0.2008778000017628
# ##############################
# ground state search for h: 0.9032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 0.00010709343361980928
# instead of the convergence tolerance 1e-12
# total time: 0.19063959998311475
# ##############################
# ground state search for h: 0.967741935483871
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1.093130558516009e-06
# instead of the convergence tolerance 1e-12
# total time: 0.2270542000187561
# ##############################
# ground state search for h: 1.032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1.589378051392032e-08
# instead of the convergence tolerance 1e-12
# total time: 0.27707750000990927
# ##############################
# ground state search for h: 1.096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 3.1325164684403717e-10
# instead of the convergence tolerance 1e-12
# total time: 0.19136080000316724
# ##############################
# ground state search for h: 1.161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 6.146194664324867e-12
# instead of the convergence tolerance 1e-12
# total time: 0.1585175000363961
# ##############################
# ground state search for h: 1.2258064516129032
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 7 sweeps at site 2
# total iterations 89
# total time: 0.17087119998177513
# ##############################
# ground state search for h: 1.2903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 7 sweeps at site 2
# total iterations 89
# total time: 0.18239380000159144
# ##############################
# ground state search for h: 1.3548387096774193
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 7 sweeps at site 2
# total iterations 89
# total time: 0.2183169000199996
# ##############################
# ground state search for h: 1.4193548387096775
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# Sweep n: 6
#
# Sweep n: 7
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 7 sweeps at site 2
# total iterations 89
# total time: 0.17964479996589944
# ##############################
# ground state search for h: 1.4838709677419355
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12896880001062527
# ##############################
# ground state search for h: 1.5483870967741935
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12690199998905882
# ##############################
# ground state search for h: 1.6129032258064515
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12593529996229336
# ##############################
# ground state search for h: 1.6774193548387095
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12734940001973882
# ##############################
# ground state search for h: 1.7419354838709677
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12121379998279735
# ##############################
# ground state search for h: 1.8064516129032258
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12465120002161711
# ##############################
# ground state search for h: 1.8709677419354838
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.1204087000223808
# ##############################
# ground state search for h: 1.935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.11673280003014952
# ##############################
# ground state search for h: 2.0
# Sweep n: 0
#
# Sweep n: 1
#
# Sweep n: 2
#
# Sweep n: 3
#
# Sweep n: 4
#
# Sweep n: 5
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 5 sweeps at site 2
# total iterations 67
# total time: 0.12741710001137108
# ##############################
# ground state search for h: 0.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.10221889999229461
# ##############################
# ground state search for h: 0.06451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.09808409999823198
# ##############################
# ground state search for h: 0.12903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.11416910000843927
# ##############################
# ground state search for h: 0.1935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.11679140001069754
# ##############################
# ground state search for h: 0.25806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.12006300000939518
# ##############################
# ground state search for h: 0.3225806451612903
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.13088999997125939
# ##############################
# ground state search for h: 0.3870967741935484
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.12393150001298636
# ##############################
# ground state search for h: 0.45161290322580644
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16655080002965406
# ##############################
# ground state search for h: 0.5161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1940343999885954
# ##############################
# ground state search for h: 0.5806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.203682099992875
# ##############################
# ground state search for h: 0.6451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1836973000317812
# ##############################
# ground state search for h: 0.7096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1531113000237383
# ##############################
# ground state search for h: 0.7741935483870968
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.19275230000494048
# ##############################
# ground state search for h: 0.8387096774193548
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.19212550000520423
# ##############################
# ground state search for h: 0.9032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.2380789999733679
# ##############################
# ground state search for h: 0.967741935483871
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1920063000288792
# ##############################
# ground state search for h: 1.032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.19309379998594522
# ##############################
# ground state search for h: 1.096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.17208609997760504
# ##############################
# ground state search for h: 1.161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16138359997421503
# ##############################
# ground state search for h: 1.2258064516129032
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.24493789998814464
# ##############################
# ground state search for h: 1.2903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.23559519997797906
# ##############################
# ground state search for h: 1.3548387096774193
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.2569843999808654
# ##############################
# ground state search for h: 1.4193548387096775
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1636030999943614
# ##############################
# ground state search for h: 1.4838709677419355
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.18374039995251223
# ##############################
# ground state search for h: 1.5483870967741935
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.18817390000913292
# ##############################
# ground state search for h: 1.6129032258064515
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.17077740002423525
# ##############################
# ground state search for h: 1.6774193548387095
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16135579999536276
# ##############################
# ground state search for h: 1.7419354838709677
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16279339999891818
# ##############################
# ground state search for h: 1.8064516129032258
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16114440001547337
# ##############################
# ground state search for h: 1.8709677419354838
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16277930000796914
# ##############################
# ground state search for h: 1.935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.16452509997179732
# ##############################
# ground state search for h: 2.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.24039130000164732
# ##############################
# ground state search for h: 0.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.20274440001230687
# ##############################
# ground state search for h: 0.06451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.21340589999454096
# ##############################
# ground state search for h: 0.12903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1658432999975048
# ##############################
# ground state search for h: 0.1935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.18600019998848438
# ##############################
# ground state search for h: 0.25806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.25905489997239783
# ##############################
# ground state search for h: 0.3225806451612903
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.22154620004585013
# ##############################
# ground state search for h: 0.3870967741935484
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.2276292000315152
# ##############################
# ground state search for h: 0.45161290322580644
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.2746185999712907
# ##############################
# ground state search for h: 0.5161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.33479150000493973
# ##############################
# ground state search for h: 0.5806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.2869432999868877
# ##############################
# ground state search for h: 0.6451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.23464109998894855
# ##############################
# ground state search for h: 0.7096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.2585041999700479
# ##############################
# ground state search for h: 0.7741935483870968
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.24529819999588653
# ##############################
# ground state search for h: 0.8387096774193548
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.26256260002264753
# ##############################
# ground state search for h: 0.9032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.24956829997245222
# ##############################
# ground state search for h: 0.967741935483871
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.3515427999664098
# ##############################
# ground state search for h: 1.032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.4410148999886587
# ##############################
# ground state search for h: 1.096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.3041901999968104
# ##############################
# ground state search for h: 1.161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.27083049999782816
# ##############################
# ground state search for h: 1.2258064516129032
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.21190860000206158
# ##############################
# ground state search for h: 1.2903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.21617740002693608
# ##############################
# ground state search for h: 1.3548387096774193
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.21038010000484064
# ##############################
# ground state search for h: 1.4193548387096775
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.22030059999087825
# ##############################
# ground state search for h: 1.4838709677419355
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.22398559999419376
# ##############################
# ground state search for h: 1.5483870967741935
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.21450940001523122
# ##############################
# ground state search for h: 1.6129032258064515
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.20569269999396056
# ##############################
# ground state search for h: 1.6774193548387095
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1984130999771878
# ##############################
# ground state search for h: 1.7419354838709677
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1963314000167884
# ##############################
# ground state search for h: 1.8064516129032258
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.19743920001201332
# ##############################
# ground state search for h: 1.8709677419354838
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.1905323999817483
# ##############################
# ground state search for h: 1.935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.20881889999145642
# ##############################
# ground state search for h: 2.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.18845039996085688
# ##############################
# ground state search for h: 0.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.3171573000145145
# ##############################
# ground state search for h: 0.06451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5537321000010706
# ##############################
# ground state search for h: 0.12903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5588893000385724
# ##############################
# ground state search for h: 0.1935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5903567000059411
# ##############################
# ground state search for h: 0.25806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6032332999748178
# ##############################
# ground state search for h: 0.3225806451612903
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6206009999732487
# ##############################
# ground state search for h: 0.3870967741935484
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6426638000411913
# ##############################
# ground state search for h: 0.45161290322580644
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6392579000093974
# ##############################
# ground state search for h: 0.5161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.7186310000251979
# ##############################
# ground state search for h: 0.5806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6581266000284813
# ##############################
# ground state search for h: 0.6451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.643991700024344
# ##############################
# ground state search for h: 0.7096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6363908000057563
# ##############################
# ground state search for h: 0.7741935483870968
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6491496000089683
# ##############################
# ground state search for h: 0.8387096774193548
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.7401915999944322
# ##############################
# ground state search for h: 0.9032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.9106138000497594
# ##############################
# ground state search for h: 0.967741935483871
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8519042999832891
# ##############################
# ground state search for h: 1.032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8236518000485376
# ##############################
# ground state search for h: 1.096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.7623698000097647
# ##############################
# ground state search for h: 1.161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6994749000295997
# ##############################
# ground state search for h: 1.2258064516129032
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.7551175999687985
# ##############################
# ground state search for h: 1.2903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.7336984999710694
# ##############################
# ground state search for h: 1.3548387096774193
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6190535999485292
# ##############################
# ground state search for h: 1.4193548387096775
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6519955999683589
# ##############################
# ground state search for h: 1.4838709677419355
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.6271992999827489
# ##############################
# ground state search for h: 1.5483870967741935
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.576136999996379
# ##############################
# ground state search for h: 1.6129032258064515
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5680577000021003
# ##############################
# ground state search for h: 1.6774193548387095
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5547452999744564
# ##############################
# ground state search for h: 1.7419354838709677
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5644429999520071
# ##############################
# ground state search for h: 1.8064516129032258
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5659250000026077
# ##############################
# ground state search for h: 1.8709677419354838
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5353544999961741
# ##############################
# ground state search for h: 1.935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5458617000258528
# ##############################
# ground state search for h: 2.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5311278000008315
# ##############################
# ground state search for h: 0.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.4813284000265412
# ##############################
# ground state search for h: 0.06451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.96799390000524
# ##############################
# ground state search for h: 0.12903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0903425000142306
# ##############################
# ground state search for h: 0.1935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1226660000393167
# ##############################
# ground state search for h: 0.25806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0586599000380374
# ##############################
# ground state search for h: 0.3225806451612903
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0396823000046425
# ##############################
# ground state search for h: 0.3870967741935484
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0267029000096954
# ##############################
# ground state search for h: 0.45161290322580644
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0221081999479793
# ##############################
# ground state search for h: 0.5161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0380061999894679
# ##############################
# ground state search for h: 0.5806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0383484999765642
# ##############################
# ground state search for h: 0.6451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1892265999922529
# ##############################
# ground state search for h: 0.7096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.2924043000093661
# ##############################
# ground state search for h: 0.7741935483870968
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1266113999881782
# ##############################
# ground state search for h: 0.8387096774193548
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3968899000319652
# ##############################
# ground state search for h: 0.9032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0962434000102803
# ##############################
# ground state search for h: 0.967741935483871
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1162743999739178
# ##############################
# ground state search for h: 1.032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1608786000288092
# ##############################
# ground state search for h: 1.096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.2058687999960966
# ##############################
# ground state search for h: 1.161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0412603000295348
# ##############################
# ground state search for h: 1.2258064516129032
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1182339999941178
# ##############################
# ground state search for h: 1.2903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.926492300000973
# ##############################
# ground state search for h: 1.3548387096774193
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.043118300032802
# ##############################
# ground state search for h: 1.4193548387096775
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1646881999913603
# ##############################
# ground state search for h: 1.4838709677419355
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.9914326000143774
# ##############################
# ground state search for h: 1.5483870967741935
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1944581000134349
# ##############################
# ground state search for h: 1.6129032258064515
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.9212427999591455
# ##############################
# ground state search for h: 1.6774193548387095
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8926111999899149
# ##############################
# ground state search for h: 1.7419354838709677
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8583821000065655
# ##############################
# ground state search for h: 1.8064516129032258
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8437251999857835
# ##############################
# ground state search for h: 1.8709677419354838
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8458783999667503
# ##############################
# ground state search for h: 1.935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8101900999899954
# ##############################
# ground state search for h: 2.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.8334330000216141
# ##############################
# ground state search for h: 0.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 0.5132703999988735
# ##############################
# ground state search for h: 0.06451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.4245047000003979
# ##############################
# ground state search for h: 0.12903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3450029999949038
# ##############################
# ground state search for h: 0.1935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3706603000173345
# ##############################
# ground state search for h: 0.25806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.2837984000216238
# ##############################
# ground state search for h: 0.3225806451612903
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3263280000537634
# ##############################
# ground state search for h: 0.3870967741935484
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.2947021000436507
# ##############################
# ground state search for h: 0.45161290322580644
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.2966387000051327
# ##############################
# ground state search for h: 0.5161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3127342000370845
# ##############################
# ground state search for h: 0.5806451612903225
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3325082999654114
# ##############################
# ground state search for h: 0.6451612903225806
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3259496000246145
# ##############################
# ground state search for h: 0.7096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3425608999677934
# ##############################
# ground state search for h: 0.7741935483870968
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3358977000461891
# ##############################
# ground state search for h: 0.8387096774193548
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.308225399989169
# ##############################
# ground state search for h: 0.9032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.6192513999994844
# ##############################
# ground state search for h: 0.967741935483871
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.4360278000240214
# ##############################
# ground state search for h: 1.032258064516129
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.504486799996812
# ##############################
# ground state search for h: 1.096774193548387
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.4384080999880098
# ##############################
# ground state search for h: 1.161290322580645
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3327126000076532
# ##############################
# ground state search for h: 1.2258064516129032
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.4067454999894835
# ##############################
# ground state search for h: 1.2903225806451613
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3963128000032157
# ##############################
# ground state search for h: 1.3548387096774193
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.267331400013063
# ##############################
# ground state search for h: 1.4193548387096775
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.3530241000116803
# ##############################
# ground state search for h: 1.4838709677419355
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.337233100028243
# ##############################
# ground state search for h: 1.5483870967741935
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.33409830002347
# ##############################
# ground state search for h: 1.6129032258064515
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.4448561000172049
# ##############################
# ground state search for h: 1.6774193548387095
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.161729700048454
# ##############################
# ground state search for h: 1.7419354838709677
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0382635000278242
# ##############################
# ground state search for h: 1.8064516129032258
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.0405445999931544
# ##############################
# ground state search for h: 1.8709677419354838
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.181871599983424
# ##############################
# ground state search for h: 1.935483870967742
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1332369999727234
# ##############################
# ground state search for h: 2.0
# Sweep n: 0
#
# Sweep n: 1
#
# ##############################
# The energy between the two last updated states converged
# to an order of 1e-12 after:
# 1 sweeps at site 2
# total iterations 23
# total time: 1.1125583000248298
# ##############################

# %%
mag_exact = []
ene_exact = []
v0 = np.full(2**L, (1/np.sqrt(2))**L)
sparse = True
for h in grid:
    H = Ising(L=L, h=h, eps=eps)
    e, v = diagonalization(H, sparse=sparse, v0=v0)
    gs = v[:,0]
    ene_exact.append(e[0])
    mag_exact.append((gs.conjugate().T @ magnetization(L=L) @ gs).real)
    v0 = gs

# %%
colors = create_sequential_colors(len(chis), colormap_name='viridis')
i = 0
for m, chi in zip(mag, chis):
    plt.plot(grid, m, 'o', color=colors[i], label=f"$\chi={chi}$")
    i += 1

plt.plot(grid, mag_exact, '-', color='red', linewidth=0.7, label="exact")
plt.title(f'Magnetization - L={L}, $\\varepsilon ={eps}$')
plt.legend()
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_19188\3645809416.py:4: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(grid, m, 'o', color=colors[i], label=f"$\chi={chi}$")

# %%
colors = create_sequential_colors(len(chis), colormap_name='viridis')
i = 0
for o, chi in zip(overlap, chis):
    plt.plot(grid, np.abs(o), 'x-', color=colors[i], label=f"$\chi={chi}$")
    i += 1

plt.title(f'Overlap - L={L}, $\\varepsilon ={eps}$')
plt.legend()
plt.show()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# <>:4: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_19188\3863098653.py:4: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(grid, np.abs(o), 'x-', color=colors[i], label=f"$\chi={chi}$")

# %%
i = 0
for e, chi in zip(ene, chis):
    plt.plot(grid, e, 'x', color=colors[i], label=f"$\chi={chi}$")
    i += 1
plt.plot(grid, ene_exact, '-', color='red', linewidth=0.7, label="exact")
plt.title(f'Energy - L={L}, $\\varepsilon ={eps}$')
plt.legend()
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_19188\2763005083.py:3: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(grid, e, 'x', color=colors[i], label=f"$\chi={chi}$")

# %%
i = 0
for e, chi in zip(entr, chis):
    plt.plot(grid, e, 'x-', color=colors[i], linewidth=0.7, label=f"$\chi={chi}$")
    i += 1
plt.title(f'Entropy - L={L}, $\\varepsilon ={eps}$')
plt.legend()
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_19188\2684290091.py:3: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(grid, e, 'x-', color=colors[i], linewidth=0.7, label=f"$\chi={chi}$")

# %%
i = 0
for sv_chi, chi in zip(sv, chis):
    svals_trunc = []
    for s in sv_chi:
        condition = s[0] >= 1e-15
        s_trunc = np.extract(condition, s[0])
        s = s[0][:len(s_trunc)]
        print(s)
        svals_trunc.append(s[-1])
    plt.plot(grid, svals_trunc, 'x-', color=colors[i], linewidth=0.7, label=f"$\chi={chi}$")
    i += 1
plt.yscale('log')
plt.title(f'Last Schmidt Value - L={L}, $\\varepsilon ={eps}$')
plt.legend()
plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\c'
# <>:10: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_19188\3839189104.py:10: SyntaxWarning: invalid escape sequence '\c'
#   plt.plot(grid, svals_trunc, 'x-', color=colors[i], linewidth=0.7, label=f"$\chi={chi}$")
# [1.]
# [9.99999966e-01 2.60688438e-04]
# [0.99999945 0.00104933]
# [0.99999715 0.00238617]
# [0.99999073 0.00430671]
# [0.99997644 0.00686484]
# [0.9999486  0.01013884]
# [0.99989854 0.01424495]
# [0.99981233 0.01937258]
# [0.99966507 0.02587962]
# [0.99940294 0.03455088]
# [0.99887898 0.04733688]
# [0.99754095 0.07008609]
# [0.99080257 0.13531543]
# [0.91752137 0.39768648]
# [0.93242716 0.36135797]
# [0.94698835 0.32126789]
# [0.95704968 0.28992398]
# [0.96428198 0.26487782]
# [0.96968308 0.24436594]
# [0.97384751 0.22720263]
# [0.97714337 0.21258134]
# [0.97980827 0.19993936]
# [0.98200151 0.18887307]
# [0.98383353 0.1790854 ]
# [0.98538323 0.17035228]
# [0.98670835 0.16250118]
# [0.98785213 0.15539682]
# [0.98884753 0.14893139]
# [0.98972013 0.14301768]
# [0.99049006 0.13758432]
# [0.99117335 0.1325722 ]
# [1.]
# [9.99999966e-01 2.60688562e-04 6.79570714e-08 1.76700020e-11]
# [9.99999449e-01 1.04934048e-03 1.10055293e-06 1.15928532e-09]
# [9.99997153e-01 2.38626849e-03 5.69352657e-06 1.13806601e-08]
# [9.99990723e-01 4.30731019e-03 1.85461916e-05 7.93800848e-08]
# [9.99976417e-01 6.86759695e-03 4.76666214e-05 3.30460914e-07]
# [9.99948480e-01 1.01501814e-02 1.10027525e-04 1.13195333e-06]
