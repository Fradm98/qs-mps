# %%
import matplotlib.pyplot as plt
import numpy as np
from qs_mps.utils import load_list_of_lists, tensor_shapes
from qs_mps.mps_class import MPS
from scipy.optimize import curve_fit

# %%
en_charges = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x5_2_particle(s)_sector_[1, 4]-[2, 2]_h_0.001-0.01_delta_10_chi_200")
en_vacuum = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x5_vacuum_sector_None-None_h_0.001-0.01_delta_10_chi_200")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\HP\AppData\Local\Temp\ipykernel_10276\2336965052.py:1: SyntaxWarning: invalid escape sequence '\M'
#   en_charges = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x5_2_particle(s)_sector_[1, 4]-[2, 2]_h_0.001-0.01_delta_10_chi_200")
# C:\Users\HP\AppData\Local\Temp\ipykernel_10276\2336965052.py:2: SyntaxWarning: invalid escape sequence '\M'
#   en_vacuum = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x5_vacuum_sector_None-None_h_0.001-0.01_delta_10_chi_200")

# %%
plt.plot(np.abs(en_charges), label="2-particle sector")
plt.plot(np.abs(en_vacuum), label="vacuum sector")
plt.yscale('log')
plt.legend()
plt.show()

# %%
interval = np.logspace(np.log10(1),np.log10(1e+10),10)
delta_energy = np.abs(np.asarray(en_charges)-np.asarray(en_vacuum)).flatten()

def func(x,a,R):
    return a + 2*x*R

popt, copt = curve_fit(func, interval, delta_energy)
print(f"R: {popt[1]}")

plt.plot(interval, delta_energy, 'o', label="energy diff")
plt.plot(interval, func(interval,popt[0],popt[1]), label="fit")
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()
# Out:
# R: 3.000000000007216

# %%
np.logspace(-5,5,10)
# Out:
# array([1.00000000e-05, 1.29154967e-04, 1.66810054e-03, 2.15443469e-02,
#        2.78255940e-01, 3.59381366e+00, 4.64158883e+01, 5.99484250e+02,
#        7.74263683e+03, 1.00000000e+05])

# %%
# interval = np.logspace(-5,5,10)
interval = np.linspace(0.001,0.01,10)
delta_energy = np.abs(np.asarray(en_charges)-np.asarray(en_vacuum)).flatten()

def func(x,a,b,c,R):
    return a*(x**2) + b*np.exp(-R/x) + c

popt, copt = curve_fit(func, interval, delta_energy)
print(f"R: {popt[3]}")

plt.plot(interval, delta_energy, 'o', label="energy diff")
plt.plot(interval, func(interval,popt[0],popt[1],popt[2],popt[3]), label="fit")
# plt.plot(interval[:5], func(interval[:5],1,1,0,3), label="fit")

plt.yscale('log')
plt.xscale('log')
# plt.ylim(1e-12,1e-7)
plt.legend()
plt.show()
# Out:
# c:\Users\HP\anaconda3\envs\mps\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# R: 1.0

# %%
interval = np.logspace(-5,5,10)
plt.plot(interval, delta_energy, 'o', label="energy diff")
plt.yscale('log')
plt.xscale('log')

# %%
en_charges = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x4_2_particle(s)_sector_[1, 3]-[2, 2]_h_0.001-1.0_delta_20_chi_50")
en_vacuum = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x4_vacuum_sector_None-None_h_0.001-1.0_delta_20_chi_50")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\HP\AppData\Local\Temp\ipykernel_10276\3978568123.py:1: SyntaxWarning: invalid escape sequence '\M'
#   en_charges = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x4_2_particle(s)_sector_[1, 3]-[2, 2]_h_0.001-1.0_delta_20_chi_50")
# C:\Users\HP\AppData\Local\Temp\ipykernel_10276\3978568123.py:2: SyntaxWarning: invalid escape sequence '\M'
#   en_vacuum = load_list_of_lists("G:\My Drive\projects\\1_Z2\\results\energy_data\energies_Z2_dual_direct_lattice_4x4_vacuum_sector_None-None_h_0.001-1.0_delta_20_chi_50")

# %%
# interval = np.logspace(-5,1,20)
interval = np.linspace(0.001,1,20)
delta_energy = np.abs(np.asarray(en_charges)-np.asarray(en_vacuum)).flatten()

def func(x,a,b,c,R):
    return a*(x**2) + b*np.exp(-R/x) + c

popt, copt = curve_fit(func, interval, delta_energy, [1,1,0,2])
print(f"R: {popt[3]}")

plt.plot(interval, delta_energy, 'o', label="energy diff")
plt.plot(interval, func(interval,popt[0],popt[1],popt[2],popt[3]), label="fit")
# plt.plot(interval, func(interval,1,1,0,2), label="fit")
#
# plt.yscale('log')
# plt.xscale('log')
# plt.ylim(1e-12,1e-7)
plt.legend()
plt.show()
# Out:
# R: 1.9639571536953444

# %%
1/np.sqrt(3.044)
1/3.044
# Out:
# 0.5731623781225857

# %% [markdown]
# ## Time evolution of a string

# %%
path_tensor = "D:/code/projects/1_Z2"
charges_x = [1,3]
charges_y = [2,2]
precision = 2
lattice_mps = MPS(L=5,d=16, model="Z2_dual", chi=50, h=0.001)
lattice_mps.L = lattice_mps.L - 1
lattice_mps.Z2.add_charges(charges_x,charges_y)
lattice_mps.load_sites(path=path_tensor, precision=precision, cx=charges_x, cy=charges_y)

# %%
lattice_mps.TEBD_variational_Z2(trotter_steps=10, delta=0.1, h_ev=0.1, quench="global", flip=False)
# Out:
# ------ Trotter steps: 0 -------
# mpo_site:0, ladder:1
# mpo_site:1, ladder:1
# mpo_site:2, ladder:1
# mpo_site:3, ladder:1
# Bond dim ancilla: 50
# Bond dim site: 50
# Sweep n: 0
# C:\Users\HP\Desktop\qs-mps\src\qs_mps\mpo_class.py:299: RuntimeWarning: invalid value encountered in sqrt
#   1j * np.sqrt(np.sin(c_int * self.lamb * delta)) * Z,
# C:\Users\HP\Desktop\qs-mps\src\qs_mps\mpo_class.py:307: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(np.sin(c_int * self.lamb * delta)) * Z,
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 lattice_mps.TEBD_variational_Z2(trotter_steps=10, delta=0.1, h_ev=0.1, quench="global", flip=False)
#
# File ~\Desktop\qs-mps\src\qs_mps\mps_class.py:2394, in MPS.TEBD_variational_Z2(self, trotter_steps, delta, h_ev, quench, flip, n_sweeps, conv_tol, fidelity, bond, where)
#    2391     print(f"Bond dim site: {self.sites[self.L//2].shape[0]}")
#    2393     # compress the ladder evolution operator
# -> 2394     error, entropy = self.compression(
#    2395         trunc_tol=False,
#    2396         trunc_chi=True,
#    2397         n_sweeps=n_sweeps,
#    2398         conv_tol=conv_tol,
#    2399         bond=bond,
#    2400         where=where,
#    2401     )
#    2402     self.ancilla_sites = self.sites.copy()
#    2404 # finish with the other half mu_x on each ladder
#
# File ~\Desktop\qs-mps\src\qs_mps\mps_class.py:2050, in MPS.compression(self, trunc_tol, trunc_chi, schmidt_tol, n_sweeps, conv_tol, where, bond)
#    2037 errors.append(errs)
#    2039 # s = self.update_state_ev(
#    2040 #     sweeps[0],
#    2041 #     sites[i],
#    (...)
#    2048 #     precision,
#    2049 # )
# -> 2050 s = self.update_state(
#    2051     sweep=sweeps[0],
#    2052     site=sites[i],
#    2053     trunc_tol=trunc_tol,
#    2054     trunc_chi=trunc_chi,
#    2055     schmidt_tol=schmidt_tol,
#    2056 )
#    2057 if bond:
#    2058     if sites[i] - 1 == where:
#
# File ~\Desktop\qs-mps\src\qs_mps\mps_class.py:1517, in MPS.update_state(self, sweep, site, trunc_tol, trunc_chi, schmidt_tol)
#    1512 if sweep == "right":
#    1513     # we want to write M (left,d,right) in LFC -> (left*d,right)
#    1514     m = self.sites[site - 1].reshape(
#    1515         self.env_left[-1].shape[2] * self.d, self.env_right[-1].shape[2]
#    1516     )
# -> 1517     u, s, v = np.linalg.svd(m, full_matrices=False)
#    1518     if trunc_tol:
#    1519         condition = s >= schmidt_tol
#
# File c:\Users\HP\anaconda3\envs\mps\Lib\site-packages\numpy\linalg\linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# File c:\Users\HP\anaconda3\envs\mps\Lib\site-packages\numpy\linalg\linalg.py:121, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     120 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 121     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
# Out:
# 5
