# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for L in [20,40]:
    mag = np.load(f"G:/My Drive/projects/3_CLUSTER/results/mag_data/mag_first_moment_Cluster_L_{L}_h_0.01-2.0_delta_50_chi_50.npy")
    # m = np.array_split(mag, 50)
    plt.imshow(mag, cmap="inferno", alpha=0.5)

hs_y = np.linspace(0,2,5)
hs_x = np.linspace(0,2,5)
x = np.linspace(0,49,5)
y = np.linspace(0,49,5)
plt.xticks(x, hs_x)
plt.yticks(y, hs_y)
plt.colorbar()
# plt.savefig("/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/figures/magnetization/loc_mag_ANNNI_L_50_xx_interaction_chi_64_measuring_z.png")
plt.show()

# %%
L = 40
mag = np.load(f"G:/My Drive/projects/3_CLUSTER/results/mag_data/mag_X_first_moment_Cluster_L_{L}_h_-2.0-2.01_delta_64_chi_50.npy")
plt.title("Magnetization of $\sigma^X$ ; Cluster $L=40$")
plt.imshow(mag, cmap="inferno")

hs_y = np.linspace(-2,2,5)
hs_x = np.linspace(-2,2,5)
x = np.linspace(0,63,5)
y = np.linspace(0,63,5)
plt.xticks(x, hs_x)
plt.yticks(y, hs_y)
plt.colorbar()
plt.savefig("G:/My Drive/projects/3_CLUSTER/figures/magnetization/loc_mag_Cluster_L_40_chi_50_measuring_x_pos_neg_64_points.png")
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_4196\755157396.py:3: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("Magnetization of $\sigma^X$ ; Cluster $L=40$")

# %%
L = 40
mag = np.load(f"G:/My Drive/projects/3_CLUSTER/results/mag_data/mag_first_moment_Cluster_L_{L}_h_-2.0-2.01_delta_13_chi_50.npy")
# m = np.array_split(mag, 50)
plt.title("Magnetization of $\sigma^X$ ; Cluster $L=40$")
plt.imshow(mag, cmap="inferno")

hs_y = np.linspace(-2,2,5)
hs_x = np.linspace(-2,2,5)
x = np.linspace(0,12,5)
y = np.linspace(0,12,5)
plt.xticks(x, hs_x)
plt.yticks(y, hs_y)
plt.savefig("G:/My Drive/projects/3_CLUSTER/figures/magnetization/loc_mag_Cluster_L_40_chi_50_measuring_x_pos-neg_vals.png")
plt.colorbar()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_4196\2758730056.py:4: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("Magnetization of $\sigma^X$ ; Cluster $L=40$")
