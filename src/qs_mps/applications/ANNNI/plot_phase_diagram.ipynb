# %% [markdown]
# # Phase Diagram of the ANNNI model
#
# The ANNNI model in 1D may look like a simple system but is a very first example where we combine: order, competition and disorder interactions.
# This interplay of different terms in the Hamiltonian gives rise ti a rich phase diagram.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mat = np.load(f"/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results/mag_data/magnetization_first_moment_ANNNI_L_9_h_0.0-2.0_k_0.0-2.0_delta_10_chi_16.npy")
plt.imshow(mat, cmap="inferno")
plt.colorbar()
plt.show()

# %%
mat = np.load(f"/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results/mag_data/magnetization_first_moment_ANNNI_L_100_h_0.0-2.0_k_0.0-2.0_delta_10_chi_100.npy")
# mat = np.load(f"/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results/mag_data/local_magnetization_ANNNI_L_20_h_0.0-2.0_k_0.0--1.0_delta_20_chi_64.npy")

# %%
plt.title("Magnetization $L=100$ watching at sigma z")
hs_y = np.linspace(0,2,5)
hs_x = np.linspace(0,2,5)
x = np.linspace(0,9,5)
y = np.linspace(0,9,5)
plt.imshow(mat, cmap="inferno")
plt.xticks(x, hs_x)
plt.yticks(y, hs_y)
plt.colorbar()
# plt.savefig("/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/figures/magnetization/loc_mag_ANNNI_L_50_xx_interaction_chi_64_measuring_z.png")
plt.show()

# %%
from qs_mps.utils import load_list_of_lists
path_drive = "/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results"
energy = load_list_of_lists(f"{path_drive}/energy_data/energies_ANNNI_spin_100_h_0.0-2.0_k_0.0-2.0_delta_10_chi_100")
energy = np.asarray(energy)
energy = np.array_split(energy, 100)
hs_y = np.linspace(0,2,5)
hs_x = np.linspace(0,2,5)
x = np.linspace(0,9,5)
y = np.linspace(0,9,5)
plt.title("Energy $L=100$")
plt.imshow(energy, cmap="inferno")
plt.xticks(x, hs_x)
plt.yticks(y, hs_y)
plt.colorbar()
# plt.savefig("/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/figures/energy/entropy_ANNNI_L_50_xx_interaction_chi_64.png")
plt.show()

# %%
path_drive = "/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results"
Entropy = load_list_of_lists(f"{path_drive}/entropy_data/50_bond_entropy_ANNNI_spin_100_h_0.0-2.0_k_0.0-2.0_delta_10_chi_100")
Entropy = np.asarray(Entropy)
Entropy = np.array_split(Entropy, 10)
hs_y = np.linspace(0,2,5)
hs_x = np.linspace(0,2,5)
x = np.linspace(0,9,5)
y = np.linspace(0,9,5)
plt.title("Entropy $L=100$")
plt.imshow(Entropy, cmap="inferno")
plt.xticks(x, hs_x)
plt.yticks(y, hs_y)
plt.colorbar()
# plt.savefig("/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/figures/energy/entropy_ANNNI_L_50_xx_interaction_chi_64.png")
plt.show()
