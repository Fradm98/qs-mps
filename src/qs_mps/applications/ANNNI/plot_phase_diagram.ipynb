# %% [markdown]
# # Phase Diagram of the ANNNI model
#
# The ANNNI model in 1D may look like a simple system but is a very first example where we combine: order, competition and disorder interactions.
# This interplay of different terms in the Hamiltonian gives rise ti a rich phase diagram.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mat = np.load(f"/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results/mag_data/magnetization_first_moment_ANNNI_L_9_h_0.0-2.0_k_0.0-2.0_delta_10_chi_16.npy")
plt.imshow(mat, cmap="inferno")
plt.colorbar()
plt.show()

# %%
# mat = np.load(f"/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results/mag_data/magnetization_first_moment_ANNNI_L_20_h_0.0-2.0_k_0.0--2.0_delta_10_chi_64.npy")
mat = np.load(f"/Users/fradm98/Library/CloudStorage/GoogleDrive-fra.di.marcantonio@gmail.com/My Drive/projects/2_ANNNI/results/mag_data/local_magnetization_ANNNI_L_20_h_0.0-2.0_k_0.0--2.0_delta_10_chi_64.npy")
plt.title("Local Magnetization $L=100$")
hs = np.linspace(0,2,5)
x = np.linspace(0,9,5)
plt.imshow(mat, cmap="inferno")
plt.xticks(x, hs)
plt.yticks(x, hs)
plt.colorbar()
plt.show()
