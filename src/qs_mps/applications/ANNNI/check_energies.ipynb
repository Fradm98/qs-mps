# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
energies = np.load("G:\My Drive\projects\\3_CLUSTER\\results\energy_data\energy_ANNNI_L_12_k_0.001-1.5_h_0.001-1.5_delta_32_chi_16.npy")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\HP\AppData\Local\Temp\ipykernel_22100\1754146375.py:1: SyntaxWarning: invalid escape sequence '\M'
#   energies = np.load("G:\My Drive\projects\\3_CLUSTER\\results\energy_data\energy_ANNNI_L_12_k_0.001-1.5_h_0.001-1.5_delta_32_chi_16.npy")

# %%
plt.matshow(energies, origin='lower')

# %%
energies = np.load("G:\My Drive\projects\\3_CLUSTER\\results\energy_data\energies_ANNNI_L_12_k_0.001-1.5_h_0.001-1.5_delta_32_chi_16.npy")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\HP\AppData\Local\Temp\ipykernel_22100\862661757.py:1: SyntaxWarning: invalid escape sequence '\M'
#   energies = np.load("G:\My Drive\projects\\3_CLUSTER\\results\energy_data\energies_ANNNI_L_12_k_0.001-1.5_h_0.001-1.5_delta_32_chi_16.npy")

# %%
hxs = np.linspace(0.001,1.5,32)
hys = np.linspace(0.001,1.5,32)
params = [[i,j] for i,hx in enumerate(hxs) for j,hy in enumerate(hys)]
energy_densities = [np.abs(energies[i,j,-1]-energies[i,j])/12 for i,hx in enumerate(hxs) for j,hy in enumerate(hys)]
for i,ed in enumerate(energy_densities):
    plt.plot(ed, label=f"param: {params[i][0]},{params[i][1]}")
plt.legend()
plt.yscale('log')
plt.show()

# %%
len(energies)
# Out:
# 3
